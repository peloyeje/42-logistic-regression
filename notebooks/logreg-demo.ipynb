# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np

from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from src.logistic_regression import LogisticRegression

# %%
train = pd.read_csv('data/dataset_train.csv', index_col=0)
test = pd.read_csv('data/dataset_test.csv', index_col=0)

train = train.fillna(0)
test = test.fillna(0)

# %%
logreg = LogisticRegression(threshold=1e-3, algorithm='gd')
scaler = StandardScaler()

# %% [markdown]
# ## Train

# %%
X = train.iloc[:, 5:]
y = train.iloc[:, 0]

# %%
X = scaler.fit_transform(X)

# %%
logreg.fit(X=X, y=y)
# Out:
# Training model for class "Gryffindor"
# /Users/JEP/Code/msc-x/42-logistic-regression/src/logistic_regression.py:70: RuntimeWarning: divide by zero encountered in log
#   y * np.log(cls._model(X, b)) + (1 - y) * np.log(1 - cls._model(X, b))
# /Users/JEP/Code/msc-x/42-logistic-regression/src/logistic_regression.py:70: RuntimeWarning: invalid value encountered in multiply
#   y * np.log(cls._model(X, b)) + (1 - y) * np.log(1 - cls._model(X, b))
# Training model for class "Hufflepuff"
# Convergence reached in 543 iterations, exiting the loop ...
# Training model for class "Ravenclaw"
# Convergence reached in 635 iterations, exiting the loop ...
# Training model for class "Slytherin"
# Convergence reached in 729 iterations, exiting the loop ...

# %%
logreg.plot()

# %% [markdown]
# ## Test

# %%
X = test.iloc[:, 5:]
X = scaler.transform(X)

# %%
logreg.predict(X)
# Out:
# array(['Hufflepuff', 'Ravenclaw', 'Gryffindor', 'Hufflepuff',
#        'Hufflepuff', 'Slytherin', 'Ravenclaw', 'Hufflepuff', 'Ravenclaw',
#        'Hufflepuff', 'Hufflepuff', 'Slytherin', 'Slytherin', 'Slytherin',
#        'Slytherin', 'Hufflepuff', 'Ravenclaw', 'Slytherin', 'Ravenclaw',
#        'Hufflepuff', 'Hufflepuff', 'Slytherin', 'Ravenclaw', 'Ravenclaw',
#        'Hufflepuff', 'Hufflepuff', 'Ravenclaw', 'Slytherin', 'Gryffindor',
#        'Ravenclaw', 'Hufflepuff', 'Hufflepuff', 'Gryffindor',
#        'Hufflepuff', 'Hufflepuff', 'Ravenclaw', 'Gryffindor', 'Ravenclaw',
#        'Slytherin', 'Ravenclaw', 'Ravenclaw', 'Slytherin', 'Hufflepuff',
#        'Slytherin', 'Hufflepuff', 'Ravenclaw', 'Slytherin', 'Gryffindor',
#        'Ravenclaw', 'Slytherin', 'Ravenclaw', 'Hufflepuff', 'Ravenclaw',
#        'Ravenclaw', 'Hufflepuff', 'Slytherin', 'Slytherin', 'Ravenclaw',
#        'Hufflepuff', 'Gryffindor', 'Gryffindor', 'Gryffindor',
#        'Hufflepuff', 'Hufflepuff', 'Ravenclaw', 'Hufflepuff',
#        'Hufflepuff', 'Ravenclaw', 'Hufflepuff', 'Ravenclaw', 'Slytherin',
#        'Slytherin', 'Gryffindor', 'Ravenclaw', 'Gryffindor', 'Hufflepuff',
#        'Hufflepuff', 'Gryffindor', 'Ravenclaw', 'Gryffindor', 'Ravenclaw',
#        'Hufflepuff', 'Slytherin', 'Gryffindor', 'Gryffindor',
#        'Hufflepuff', 'Hufflepuff', 'Hufflepuff', 'Ravenclaw', 'Ravenclaw',
#        'Hufflepuff', 'Slytherin', 'Gryffindor', 'Hufflepuff', 'Ravenclaw',
#        'Ravenclaw', 'Gryffindor', 'Slytherin', 'Hufflepuff', 'Ravenclaw',
#        'Hufflepuff', 'Hufflepuff', 'Hufflepuff', 'Slytherin', 'Ravenclaw',
#        'Ravenclaw', 'Hufflepuff', 'Slytherin', 'Slytherin', 'Hufflepuff',
#        'Hufflepuff', 'Slytherin', 'Gryffindor', 'Ravenclaw', 'Hufflepuff',
#        'Ravenclaw', 'Ravenclaw', 'Hufflepuff', 'Slytherin', 'Ravenclaw',
#        'Gryffindor', 'Hufflepuff', 'Gryffindor', 'Gryffindor',
#        'Ravenclaw', 'Ravenclaw', 'Slytherin', 'Ravenclaw', 'Hufflepuff',
#        'Ravenclaw', 'Ravenclaw', 'Gryffindor', 'Gryffindor', 'Slytherin',
#        'Hufflepuff', 'Ravenclaw', 'Ravenclaw', 'Slytherin', 'Gryffindor',
#        'Hufflepuff', 'Hufflepuff', 'Ravenclaw', 'Gryffindor', 'Ravenclaw',
#        'Gryffindor', 'Ravenclaw', 'Ravenclaw', 'Hufflepuff', 'Hufflepuff',
#        'Ravenclaw', 'Hufflepuff', 'Gryffindor', 'Gryffindor', 'Ravenclaw',
#        'Ravenclaw', 'Gryffindor', 'Hufflepuff', 'Slytherin', 'Hufflepuff',
#        'Ravenclaw', 'Ravenclaw', 'Hufflepuff', 'Hufflepuff', 'Hufflepuff',
#        'Ravenclaw', 'Slytherin', 'Hufflepuff', 'Hufflepuff', 'Hufflepuff',
#        'Hufflepuff', 'Gryffindor', 'Hufflepuff', 'Hufflepuff',
#        'Slytherin', 'Hufflepuff', 'Gryffindor', 'Gryffindor',
#        'Hufflepuff', 'Hufflepuff', 'Slytherin', 'Ravenclaw', 'Ravenclaw',
#        'Gryffindor', 'Slytherin', 'Gryffindor', 'Gryffindor',
#        'Hufflepuff', 'Ravenclaw', 'Hufflepuff', 'Slytherin', 'Gryffindor',
#        'Hufflepuff', 'Gryffindor', 'Ravenclaw', 'Ravenclaw', 'Hufflepuff',
#        'Ravenclaw', 'Hufflepuff', 'Hufflepuff', 'Gryffindor',
#        'Gryffindor', 'Hufflepuff', 'Ravenclaw', 'Hufflepuff',
#        'Gryffindor', 'Slytherin', 'Ravenclaw', 'Hufflepuff', 'Gryffindor',
#        'Ravenclaw', 'Gryffindor', 'Hufflepuff', 'Slytherin', 'Ravenclaw',
#        'Slytherin', 'Slytherin', 'Hufflepuff', 'Hufflepuff', 'Gryffindor',
#        'Gryffindor', 'Gryffindor', 'Gryffindor', 'Hufflepuff',
#        'Hufflepuff', 'Gryffindor', 'Ravenclaw', 'Ravenclaw', 'Ravenclaw',
#        'Hufflepuff', 'Hufflepuff', 'Gryffindor', 'Hufflepuff',
#        'Slytherin', 'Ravenclaw', 'Hufflepuff', 'Hufflepuff', 'Hufflepuff',
#        'Slytherin', 'Gryffindor', 'Gryffindor', 'Hufflepuff',
#        'Gryffindor', 'Hufflepuff', 'Hufflepuff', 'Gryffindor',
#        'Gryffindor', 'Ravenclaw', 'Ravenclaw', 'Hufflepuff', 'Hufflepuff',
#        'Slytherin', 'Slytherin', 'Hufflepuff', 'Hufflepuff', 'Ravenclaw',
#        'Ravenclaw', 'Hufflepuff', 'Ravenclaw', 'Hufflepuff', 'Ravenclaw',
#        'Slytherin', 'Ravenclaw', 'Ravenclaw', 'Hufflepuff', 'Hufflepuff',
#        'Ravenclaw', 'Ravenclaw', 'Gryffindor', 'Ravenclaw', 'Ravenclaw',
#        'Hufflepuff', 'Slytherin', 'Ravenclaw', 'Gryffindor', 'Ravenclaw',
#        'Hufflepuff', 'Ravenclaw', 'Gryffindor', 'Gryffindor',
#        'Hufflepuff', 'Hufflepuff', 'Hufflepuff', 'Hufflepuff',
#        'Ravenclaw', 'Hufflepuff', 'Ravenclaw', 'Ravenclaw', 'Slytherin',
#        'Gryffindor', 'Ravenclaw', 'Gryffindor', 'Gryffindor', 'Ravenclaw',
#        'Hufflepuff', 'Hufflepuff', 'Gryffindor', 'Slytherin',
#        'Hufflepuff', 'Hufflepuff', 'Hufflepuff', 'Hufflepuff',
#        'Hufflepuff', 'Hufflepuff', 'Hufflepuff', 'Ravenclaw', 'Slytherin',
#        'Hufflepuff', 'Ravenclaw', 'Hufflepuff', 'Slytherin', 'Hufflepuff',
#        'Hufflepuff', 'Hufflepuff', 'Gryffindor', 'Ravenclaw',
#        'Hufflepuff', 'Ravenclaw', 'Slytherin', 'Hufflepuff', 'Slytherin',
#        'Slytherin', 'Ravenclaw', 'Ravenclaw', 'Slytherin', 'Ravenclaw',
#        'Ravenclaw', 'Slytherin', 'Hufflepuff', 'Slytherin', 'Gryffindor',
#        'Ravenclaw', 'Hufflepuff', 'Gryffindor', 'Ravenclaw', 'Ravenclaw',
#        'Hufflepuff', 'Ravenclaw', 'Hufflepuff', 'Gryffindor',
#        'Hufflepuff', 'Hufflepuff', 'Slytherin', 'Ravenclaw', 'Gryffindor',
#        'Hufflepuff', 'Hufflepuff', 'Hufflepuff', 'Ravenclaw', 'Ravenclaw',
#        'Slytherin', 'Slytherin', 'Gryffindor', 'Hufflepuff', 'Ravenclaw',
#        'Slytherin', 'Hufflepuff', 'Hufflepuff', 'Hufflepuff',
#        'Gryffindor', 'Hufflepuff', 'Ravenclaw', 'Gryffindor',
#        'Gryffindor', 'Ravenclaw', 'Hufflepuff', 'Gryffindor',
#        'Hufflepuff', 'Hufflepuff', 'Gryffindor', 'Hufflepuff',
#        'Slytherin', 'Gryffindor', 'Gryffindor', 'Ravenclaw', 'Hufflepuff',
#        'Hufflepuff', 'Ravenclaw', 'Slytherin', 'Gryffindor', 'Slytherin',
#        'Gryffindor', 'Hufflepuff', 'Gryffindor', 'Gryffindor',
#        'Gryffindor', 'Gryffindor', 'Ravenclaw', 'Ravenclaw', 'Hufflepuff',
#        'Ravenclaw', 'Slytherin', 'Hufflepuff', 'Hufflepuff', 'Ravenclaw',
#        'Ravenclaw', 'Slytherin', 'Hufflepuff', 'Hufflepuff', 'Ravenclaw',
#        'Ravenclaw'], dtype='<U10')
